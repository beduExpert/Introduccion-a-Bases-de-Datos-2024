# %% [markdown]
# ## Ejemplo 01: Procesamiento de datos y carga de datos
# En este pequeño ejemplo, porcesaremos los datos de un dataset para cargarlos en una base de datos de manera programativa.
#
# No te preocupes mucho por los detalles del código y demás, todo esto lo aprenderás en tu **Módulo de Procesamiento de datos con Python**.

# %% [markdown]
# ### Importamos las bibliotecas necesarias

# %%
import pandas as pd

# %% [markdown]
# ### Cargamos el dataset en formato CSV
# Se muestra únicamente los primeros 5 registros.

# %%
df = pd.read_csv('/content/afluencia_metro_260524.csv')
df.head()
# Out:
#         fecha    mes  anio    linea  estacion  tipo_pago  afluencia
# 0  2021-01-01  Enero  2021  Línea 1  Balbuena     Boleto       1848
# 1  2021-01-01  Enero  2021  Línea 1  Balbuena    Prepago        790
# 2  2021-01-01  Enero  2021  Línea 1  Balbuena  Gratuidad        325
# 3  2021-01-01  Enero  2021  Línea 1  Balderas     Boleto       1103
# 4  2021-01-01  Enero  2021  Línea 1  Balderas    Prepago        922

# %% [markdown]
# ### Damos formato a los datos, quitamos columnas innecesarias y estructuramos para poder cargar.

# %% [markdown]
# #### (1) Añadimos una columna con el dia

# %%
df['dia'] = pd.to_datetime(df['fecha']).dt.day
df.head()
# Out:
#         fecha    mes  anio    linea  estacion  tipo_pago  afluencia  dia
# 0  2021-01-01  Enero  2021  Línea 1  Balbuena     Boleto       1848    1
# 1  2021-01-01  Enero  2021  Línea 1  Balbuena    Prepago        790    1
# 2  2021-01-01  Enero  2021  Línea 1  Balbuena  Gratuidad        325    1
# 3  2021-01-01  Enero  2021  Línea 1  Balderas     Boleto       1103    1
# 4  2021-01-01  Enero  2021  Línea 1  Balderas    Prepago        922    1

# %% [markdown]
# #### (2) Volvemos numérico el mes para mayor facilidad de manipulación
# Primero debemos saber cuáles son los distintos valores de la colunmna.

# %%
df['mes'].unique()
# Out:
# array(['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio',
#        'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre', nan],
#       dtype=object)

# %%
map1 = {'Enero': 1,
        'Febrero': 2,
        'Marzo': 3,
        'Abril': 4,
        'Mayo': 5,
        'Junio': 6,
        'Julio': 7,
        'Agosto': 8,
        'Septiembre': 9,
        'Octubre': 10,
        'Noviembre': 11,
        'Diciembre': 12}

df['mes'] = df['mes'].map(map1)
df.head()
# Out:
#         fecha  mes  anio    linea  estacion  tipo_pago  afluencia  dia
# 0  2021-01-01  1.0  2021  Línea 1  Balbuena     Boleto       1848    1
# 1  2021-01-01  1.0  2021  Línea 1  Balbuena    Prepago        790    1
# 2  2021-01-01  1.0  2021  Línea 1  Balbuena  Gratuidad        325    1
# 3  2021-01-01  1.0  2021  Línea 1  Balderas     Boleto       1103    1
# 4  2021-01-01  1.0  2021  Línea 1  Balderas    Prepago        922    1

# %% [markdown]
# #### (3) Repetimos lo mismo para la línea, estación y tipo_pago
# En este caso, lo hacemos para cumplir con las formas normales y garantizar la integridad de la base de datos. Se crearán además los catálogos correspondientes para cargarlos en la base de datos.

# %%
# Líneas
df['linea'].unique()
# Out:
# array(['Línea 1', 'Línea 12', 'Línea 2', 'Línea 3', 'Línea 4', 'Línea 5',
#        'Línea 6', 'Línea 7', 'Línea 8', 'Línea 9', 'Línea A', 'Línea B'],
#       dtype=object)

# %%
map2 = {valor : i for i, valor in enumerate(df['linea'].unique())}
map2
# Out:
# {'Línea 1': 0,
#  'Línea 12': 1,
#  'Línea 2': 2,
#  'Línea 3': 3,
#  'Línea 4': 4,
#  'Línea 5': 5,
#  'Línea 6': 6,
#  'Línea 7': 7,
#  'Línea 8': 8,
#  'Línea 9': 9,
#  'Línea A': 10,
#  'Línea B': 11}

# %%
df_lineas = pd.DataFrame(list(map2.items()), columns=['descripcion', 'id_linea'])
df_lineas[['id_linea','descripcion']]
# Out:
#     id_linea descripcion
# 0          0     Línea 1
# 1          1    Línea 12
# 2          2     Línea 2
# 3          3     Línea 3
# 4          4     Línea 4
# 5          5     Línea 5
# 6          6     Línea 6
# 7          7     Línea 7
# 8          8     Línea 8
# 9          9     Línea 9
# 10        10     Línea A
# 11        11     Línea B

# %%
df_lineas[['id_linea','descripcion']].to_csv('lineas.csv', index=False)

# %%
# Estaciones
df['estacion'].unique()
# Out:
# array(['Balbuena', 'Balderas', 'Boulevard Puerto Aéreo', 'Candelaria',
#        'Chapultepec', 'Cuauhtémoc', 'Gómez Farías', 'Insurgentes',
#        'Isabel la Católica', 'Juanacatlán', 'Merced', 'Moctezuma',
#        'Observatorio', 'Pantitlán', 'Pino Suárez', 'Salto del Agua',
#        'San Lázaro', 'Sevilla', 'Tacubaya', 'Zaragoza',
#        'Hospital 20 de Noviembre', 'Atlalilco', 'Calle 11', 'Culhuacán',
#        'Eje Central', 'Ermita', 'Insurgentes Sur', 'Lomas Estrella',
#        'Mexicaltzingo', 'Mixcoac', 'Nopalera', 'Olivos',
#        'Parque de los Venados', 'Periférico Oriente',
#        'San Andrés Tomatlán', 'Tezonco', 'Tláhuac', 'Tlaltenco', 'Zapata',
#        'Zapotitlán', 'Allende', 'Bellas Artes', 'Chabacano',
#        'Colegio Militar', 'Cuatro Caminos', 'Cuitláhuac', 'General Anaya',
#        'Hidalgo', 'Nativitas', 'Normal', 'Panteones', 'Popotla',
#        'Portales', 'Revolución', 'San Antonio Abad', 'San Cosme',
#        'Tacuba', 'Tasqueña', 'Viaducto', 'Villa de Cortés', 'Xola',
#        'Zócalo/Tenochtitlan', 'Centro Médico', 'Copilco', 'Coyoacán',
#        'Deportivo 18 de Marzo', 'División del Norte',
#        'Etiopía/Plaza de la Transparencia', 'Eugenia', 'Guerrero',
#        'Hospital General', 'Indios Verdes', 'Juárez', 'La Raza',
#        'Miguel Ángel de Quevedo', 'Niños Héroes', 'Potrero', 'Tlatelolco',
#        'Universidad', 'Viveros/Derechos Humanos', 'Bondojito',
#        'Canal del Norte', 'Consulado', 'Fray Servando', 'Jamaica',
#        'Martín Carrera', 'Morelos', 'Santa Anita', 'Talismán', 'Aragón',
#        'Autobuses del Norte', 'Eduardo Molina', 'Hangares',
#        'Instituto del Petróleo', 'Misterios', 'Oceanía', 'Politécnico',
#        'Terminal Aérea', 'Valle Gómez', 'UAM-Azcapotzalco', 'El Rosario',
#        'Ferrería/Arena Ciudad de México', 'La Villa/Basílica',
#        'Lindavista', 'Norte 45', 'Tezozómoc', 'Vallejo', 'Aquiles Serdán',
#        'Auditorio', 'Barranca del Muerto', 'Camarones', 'Constituyentes',
#        'Polanco', 'Refinería', 'San Antonio', 'San Joaquín',
#        'San Pedro de los Pinos', 'Aculco', 'Apatlaco',
#        'Cerro de la Estrella', 'Constitución de 1917', 'Coyuya',
#        'Doctores', 'Escuadrón 201', 'Garibaldi/Lagunilla', 'Iztacalco',
#        'Iztapalapa', 'La Viga', 'Obrera', 'San Juan de Letrán', 'UAM-I',
#        'Chilpancingo', 'Ciudad Deportiva', 'Lázaro Cárdenas', 'Mixiuhca',
#        'Patriotismo', 'Puebla', 'Velódromo', 'Acatitla',
#        'Agrícola Oriental', 'Canal de San Juan', 'Guelatao', 'La Paz',
#        'Los Reyes', 'Peñón Viejo', 'Santa Marta', 'Tepalcates',
#        'Bosque de Aragón', 'Buenavista', 'Ciudad Azteca',
#        'Deportivo Oceanía', 'Ecatepec', 'Impulsora', 'Lagunilla',
#        'Múzquiz', 'Nezahualcóyotl', 'Olímpica', 'Plaza Aragón',
#        'Ricardo Flores Magón', 'Río de los Remedios', 'Romero Rubio',
#        'Tepito', 'Villa de Aragón'], dtype=object)

# %%
map3 = {valor : i for i, valor in enumerate(df['estacion'].unique())}
map3
# Out:
# {'Balbuena': 0,
#  'Balderas': 1,
#  'Boulevard Puerto Aéreo': 2,
#  'Candelaria': 3,
#  'Chapultepec': 4,
#  'Cuauhtémoc': 5,
#  'Gómez Farías': 6,
#  'Insurgentes': 7,
#  'Isabel la Católica': 8,
#  'Juanacatlán': 9,
#  'Merced': 10,
#  'Moctezuma': 11,
#  'Observatorio': 12,
#  'Pantitlán': 13,
#  'Pino Suárez': 14,
#  'Salto del Agua': 15,
#  'San Lázaro': 16,
#  'Sevilla': 17,
#  'Tacubaya': 18,
#  'Zaragoza': 19,
#  'Hospital 20 de Noviembre': 20,
#  'Atlalilco': 21,
#  'Calle 11': 22,
#  'Culhuacán': 23,
#  'Eje Central': 24,
#  'Ermita': 25,
#  'Insurgentes Sur': 26,
#  'Lomas Estrella': 27,
#  'Mexicaltzingo': 28,
#  'Mixcoac': 29,
#  'Nopalera': 30,
#  'Olivos': 31,
#  'Parque de los Venados': 32,
#  'Periférico Oriente': 33,
#  'San Andrés Tomatlán': 34,
#  'Tezonco': 35,
#  'Tláhuac': 36,
#  'Tlaltenco': 37,
#  'Zapata': 38,
#  'Zapotitlán': 39,
#  'Allende': 40,
#  'Bellas Artes': 41,
#  'Chabacano': 42,
#  'Colegio Militar': 43,
#  'Cuatro Caminos': 44,
#  'Cuitláhuac': 45,
#  'General Anaya': 46,
#  'Hidalgo': 47,
#  'Nativitas': 48,
#  'Normal': 49,
#  'Panteones': 50,
#  'Popotla': 51,
#  'Portales': 52,
#  'Revolución': 53,
#  'San Antonio Abad': 54,
#  'San Cosme': 55,
#  'Tacuba': 56,
#  'Tasqueña': 57,
#  'Viaducto': 58,
#  'Villa de Cortés': 59,
#  'Xola': 60,
#  'Zócalo/Tenochtitlan': 61,
#  'Centro Médico': 62,
#  'Copilco': 63,
#  'Coyoacán': 64,
#  'Deportivo 18 de Marzo': 65,
#  'División del Norte': 66,
#  'Etiopía/Plaza de la Transparencia': 67,
#  'Eugenia': 68,
#  'Guerrero': 69,
#  'Hospital General': 70,
#  'Indios Verdes': 71,
#  'Juárez': 72,
#  'La Raza': 73,
#  'Miguel Ángel de Quevedo': 74,
#  'Niños Héroes': 75,
#  'Potrero': 76,
#  'Tlatelolco': 77,
#  'Universidad': 78,
#  'Viveros/Derechos Humanos': 79,
#  'Bondojito': 80,
#  'Canal del Norte': 81,
#  'Consulado': 82,
#  'Fray Servando': 83,
#  'Jamaica': 84,
#  'Martín Carrera': 85,
#  'Morelos': 86,
#  'Santa Anita': 87,
#  'Talismán': 88,
#  'Aragón': 89,
#  'Autobuses del Norte': 90,
#  'Eduardo Molina': 91,
#  'Hangares': 92,
#  'Instituto del Petróleo': 93,
#  'Misterios': 94,
#  'Oceanía': 95,
#  'Politécnico': 96,
#  'Terminal Aérea': 97,
#  'Valle Gómez': 98,
#  'UAM-Azcapotzalco': 99,
#  'El Rosario': 100,
#  'Ferrería/Arena Ciudad de México': 101,
#  'La Villa/Basílica': 102,
#  'Lindavista': 103,
#  'Norte 45': 104,
#  'Tezozómoc': 105,
#  'Vallejo': 106,
#  'Aquiles Serdán': 107,
#  'Auditorio': 108,
#  'Barranca del Muerto': 109,
#  'Camarones': 110,
#  'Constituyentes': 111,
#  'Polanco': 112,
#  'Refinería': 113,
#  'San Antonio': 114,
#  'San Joaquín': 115,
#  'San Pedro de los Pinos': 116,
#  'Aculco': 117,
#  'Apatlaco': 118,
#  'Cerro de la Estrella': 119,
#  'Constitución de 1917': 120,
#  'Coyuya': 121,
#  'Doctores': 122,
#  'Escuadrón 201': 123,
#  'Garibaldi/Lagunilla': 124,
#  'Iztacalco': 125,
#  'Iztapalapa': 126,
#  'La Viga': 127,
#  'Obrera': 128,
#  'San Juan de Letrán': 129,
#  'UAM-I': 130,
#  'Chilpancingo': 131,
#  'Ciudad Deportiva': 132,
#  'Lázaro Cárdenas': 133,
#  'Mixiuhca': 134,
#  'Patriotismo': 135,
#  'Puebla': 136,
#  'Velódromo': 137,
#  'Acatitla': 138,
#  'Agrícola Oriental': 139,
#  'Canal de San Juan': 140,
#  'Guelatao': 141,
#  'La Paz': 142,
#  'Los Reyes': 143,
#  'Peñón Viejo': 144,
#  'Santa Marta': 145,
#  'Tepalcates': 146,
#  'Bosque de Aragón': 147,
#  'Buenavista': 148,
#  'Ciudad Azteca': 149,
#  'Deportivo Oceanía': 150,
#  'Ecatepec': 151,
#  'Impulsora': 152,
#  'Lagunilla': 153,
#  'Múzquiz': 154,
#  'Nezahualcóyotl': 155,
#  'Olímpica': 156,
#  'Plaza Aragón': 157,
#  'Ricardo Flores Magón': 158,
#  'Río de los Remedios': 159,
#  'Romero Rubio': 160,
#  'Tepito': 161,
#  'Villa de Aragón': 162}

# %%
# Estaciones
df_estaciones = df[['estacion', 'linea']].drop_duplicates()
df_estaciones['id_linea'] = df_estaciones['linea'].map(map2)
df_estaciones['id_estacion'] = df_estaciones['estacion'].map(map3)
df_estaciones = df_estaciones.rename(columns={'estacion': 'descripcion'})
df_estaciones[['id_estacion', 'id_linea', 'descripcion']]
# Out:
#      id_estacion  id_linea             descripcion
# 0              0         0                Balbuena
# 3              1         0                Balderas
# 6              2         0  Boulevard Puerto Aéreo
# 9              3         0              Candelaria
# 12             4         0             Chapultepec
# ..           ...       ...                     ...
# 570          159        11     Río de los Remedios
# 573          160        11            Romero Rubio
# 576           16        11              San Lázaro
# 579          161        11                  Tepito
# 582          162        11         Villa de Aragón
#
# [195 rows x 3 columns]

# %%
df_estaciones[['id_estacion', 'id_linea', 'descripcion']].to_csv('estaciones.csv', index=False)

# %%
# Tipo de pago
df['tipo_pago'].unique()
# Out:
# array(['Boleto', 'Prepago', 'Gratuidad'], dtype=object)

# %%
map4 = {valor : i for i, valor in enumerate(df['tipo_pago'].unique())}
map4
# Out:
# {'Boleto': 0, 'Prepago': 1, 'Gratuidad': 2}

# %%
df_tipo_pago = pd.DataFrame()
df_tipo_pago['tipo_pago'] = df['tipo_pago'].unique()
df_tipo_pago['id_tipo_pago'] = df_tipo_pago['tipo_pago'].map(map4)
df_tipo_pago = df_tipo_pago.rename(columns={'tipo_pago':'descripcion'})
df_tipo_pago[['id_tipo_pago', 'descripcion']]
# Out:
#    id_tipo_pago descripcion
# 0             0      Boleto
# 1             1     Prepago
# 2             2   Gratuidad

# %%
df_tipo_pago[['id_tipo_pago', 'descripcion']].to_csv('pago.csv', index=False)

# %% [markdown]
# #### (4) Generamos el consolidado final

# %%
df['id_estacion'] = df['estacion'].map(map3)
df['id_tipo_pago'] = df['tipo_pago'].map(map4)
df['id_consolidado'] = df.reset_index().index
df
# Out:
#              fecha  mes  anio     linea         estacion  tipo_pago  \
# 0       2021-01-01  1.0  2021   Línea 1         Balbuena     Boleto
# 1       2021-01-01  1.0  2021   Línea 1         Balbuena    Prepago
# 2       2021-01-01  1.0  2021   Línea 1         Balbuena  Gratuidad
# 3       2021-01-01  1.0  2021   Línea 1         Balderas     Boleto
# 4       2021-01-01  1.0  2021   Línea 1         Balderas    Prepago
# ...            ...  ...   ...       ...              ...        ...
# 675670  2024-02-29  2.0  2024  Línea 12  Insurgentes Sur    Prepago
# 675671  2024-02-29  2.0  2024  Línea 12  Insurgentes Sur  Gratuidad
# 675672  2024-02-29  2.0  2024  Línea 12          Mixcoac     Boleto
# 675673  2024-02-29  2.0  2024  Línea 12          Mixcoac    Prepago
# 675674  2024-02-29  2.0  2024  Línea 12          Mixcoac  Gratuidad
#
#         afluencia  dia  id_estacion  id_tipo_pago  id_consolidado
# 0            1848    1            0             0               0
# 1             790    1            0             1               1
# 2             325    1            0             2               2
# 3            1103    1            1             0               3
# 4             922    1            1             1               4
# ...           ...  ...          ...           ...             ...
# 675670      32134   29           26             1          675670
# 675671       2852   29           26             2          675671
# 675672          0   29           29             0          675672
# 675673      14162   29           29             1          675673
# 675674       1664   29           29             2          675674
#
# [675675 rows x 11 columns]

# %%
df[['id_consolidado','dia','mes','anio','id_estacion','id_tipo_pago','afluencia']]
# Out:
#         id_consolidado  dia  mes  anio  id_estacion  id_tipo_pago  afluencia
# 0                    0    1  1.0  2021            0             0       1848
# 1                    1    1  1.0  2021            0             1        790
# 2                    2    1  1.0  2021            0             2        325
# 3                    3    1  1.0  2021            1             0       1103
# 4                    4    1  1.0  2021            1             1        922
# ...                ...  ...  ...   ...          ...           ...        ...
# 675670          675670   29  2.0  2024           26             1      32134
# 675671          675671   29  2.0  2024           26             2       2852
# 675672          675672   29  2.0  2024           29             0          0
# 675673          675673   29  2.0  2024           29             1      14162
# 675674          675674   29  2.0  2024           29             2       1664
#
# [675675 rows x 7 columns]

# %%
df[['id_consolidado','dia','mes','anio','id_estacion','id_tipo_pago','afluencia']].to_csv('consolidado.csv', index=False)
